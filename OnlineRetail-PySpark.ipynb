# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd/content/gdrive/MyDrive/707/Assgment2
# Out:
# /content/gdrive/MyDrive/707/Assgment2

# %%
ls
# Out:
#  612OnlineRetail.ipynb                OnlineRetail-PySpark.ipynb
#  707AssignmentNo2.docx                OnlineRetail_test.ipynb
#  707Wine.ipynb                        OnlineRetail.xlsx
# 'clean datasets OnlineRetails.docx'  'Real estate valuation data set.xlsx'
#  combined_data.csv                    winequality.names
#  OnlineRetail2.xlsx                   winequality-red.csv
#  online_retail_I.xlsx                 winequality-white.csv

# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.3/317.3 MB 4.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.2-py2.py3-none-any.whl size=317812365 sha256=c09cf6383c8d580f4bae84c233255449c66765a748c4432ee5b0a212207fe7a9
#   Stored in directory: /root/.cache/pip/wheels/34/34/bd/03944534c44b677cd5859f248090daa9fb27b3c8f8e5f49574
# Successfully built pyspark
# ...

# %%
# Import necessary PySpark libraries
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, sum as _sum

# %%
# Initialize Spark session
spark1 = SparkSession.builder \
    .appName("ETL Integration for Online Retail") \
    .config("spark.memory.fraction", 0.8)\
    .config("spark.executor.memory", "16g") \
    .config("spark.driver.memory", '16g')\
    .config("spark.sql.shuffle.partitions", "800")\
    .config("spark.jars.packages", "com.crealytics:spark-excel_2.12:0.13.5") \
    .getOrCreate()

# %%
spark1 = SparkSession.builder \
    .appName("ETL Integration for Online Retail") \
    .config("spark.jars.packages", "com.crealytics:spark-excel_2.12:0.13.5") \
    .getOrCreate()

# %%
# Step 1: Load Data
# Load data from Excel files

OnlineRetail1 = spark1.read.format("com.crealytics.spark.excel") \
       .option("header", "true") \
       .option("inferSchema", "true") \
       .option("maxRowsInMemory", 10000) \
       .load("OnlineRetail.xlsx").repartition(20) #Call repartition after loading the data
print("Top 20 records of Online Retail1:")
OnlineRetail1.head(20)
# Out:
# Top 20 records of Online Retail1:
# [Row(InvoiceNo=558123.0, StockCode='23112', Description='PARISIENNE CURIO CABINET', Quantity=2.0, InvoiceDate=datetime.datetime(2011, 6, 27, 10, 16), UnitPrice=7.5, CustomerID=15834.0, Country='United Kingdom'),
#  Row(InvoiceNo=559660.0, StockCode='22329', Description='ROUND CONTAINER SET OF 5 RETROSPOT', Quantity=3.0, InvoiceDate=datetime.datetime(2011, 7, 11, 13, 19), UnitPrice=1.65, CustomerID=16701.0, Country='United Kingdom'),
#  Row(InvoiceNo=553189.0, StockCode='82613B', Description='METAL SIGN,CUPCAKE SINGLE HOOK', Quantity=3.0, InvoiceDate=datetime.datetime(2011, 5, 15, 13, 14), UnitPrice=1.25, CustomerID=15033.0, Country='United Kingdom'),
#  Row(InvoiceNo=553004.0, StockCode='22171', Description='3 HOOK PHOTO SHELF ANTIQUE WHITE', Quantity=4.0, InvoiceDate=datetime.datetime(2011, 5, 12, 16, 11), UnitPrice=8.5, CustomerID=17764.0, Country='United Kingdom'),
# ...

# %%
OnlineRetail2 = spark1.read.format("com.crealytics.spark.excel") \
       .option("header", "true") \
       .option("inferSchema", "true") \
       .option("maxRowsInMemory", 10000) \
       .load("OnlineRetail.xlsx").repartition(2) #Call repartition after loading the data
print("Top 20 records of Online Retail2:")
OnlineRetail2.head(20)
# Out:
# Top 20 records of Online Retail2:
# ERROR:root:Exception while sending command.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/py4j/clientserver.py", line 516, in send_command
#     raise Py4JNetworkError("Answer from Java side is empty")
# py4j.protocol.Py4JNetworkError: Answer from Java side is empty
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/usr/local/lib/python3.10/dist-packages/py4j/clientserver.py", line 539, in send_command
#     raise Py4JNetworkError(
# py4j.protocol.Py4JNetworkError: Error while sending or receiving
# ---------------------------------------------------------------------------
# Py4JError                                 Traceback (most recent call last)
# ...

# %%
# !pip install findspark

# %%
import findspark
findspark.init()

# %%
# !pip install pyspark

# %%
spark = SparkSession.builder \
 .master("local")\
 .appName("MySparkApp") \
 .getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-42-ea3c5ae814d5> in <cell line: 1>()
#       2  .master("local")\
#       3  .appName("MySparkApp") \
# ----> 4  .getOrCreate()
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/session.py in getOrCreate(self)
#     501                 else:
#     502                     getattr(
# --> 503                         getattr(session._jvm, "SparkSession$"), "MODULE$"
#     504                     ).applyModifiableSettings(session._jsparkSession, self._options)
#     505                 return session
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __getattr__(self, name)
#    1710             return UserHelpAutoCompletion()
#    1711
# -> 1712         answer = self._gateway_client.send_command(
#    1713             proto.REFLECTION_COMMAND_NAME +
# ...

# %%
from pyspark.sql import SparkSession
SparkSession.builder.getOrCreate()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-37-7b0cf90d1996> in <cell line: 2>()
#       1 from pyspark.sql import SparkSession
# ----> 2 SparkSession.builder.getOrCreate()
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/session.py in getOrCreate(self)
#     501                 else:
#     502                     getattr(
# --> 503                         getattr(session._jvm, "SparkSession$"), "MODULE$"
#     504                     ).applyModifiableSettings(session._jsparkSession, self._options)
#     505                 return session
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __getattr__(self, name)
#    1710             return UserHelpAutoCompletion()
#    1711
# -> 1712         answer = self._gateway_client.send_command(
#    1713             proto.REFLECTION_COMMAND_NAME +
# ...

# %%
duplicate_record1 = OnlineRetail.groupBy("InvoiceNo").count().filter("count > 1")
print("Duplicate Record1:")
duplicate_record1.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-4587ecfda369> in <cell line: 1>()
# ----> 1 duplicate_record1 = OnlineRetail.groupBy("InvoiceNo").count().filter("count > 1")
#       2 print("Duplicate Record1:")
#       3 duplicate_record1.show()
#
# NameError: name 'OnlineRetail' is not defined

# %%
duplicate_record2 = OnlineRetail2.groupBy("Invoice").count().filter("count > 1")
print("Duplicate Record2:")
duplicate_record2.show()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-14-87169f124d77> in <cell line: 1>()
# ----> 1 duplicate_record2 = OnlineRetail2.groupBy("InvoiceNo").count().filter("count > 1")
#       2 print("Duplicate Record2:")
#       3 duplicate_record2.show()
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py in groupBy(self, *cols)
#    3412         +-----+---+-----+
#    3413         """
# -> 3414         jgd = self._jdf.groupBy(self._jcols(*cols))
#    3415         from pyspark.sql.group import GroupedData
#    3416
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py in _jcols(self, *cols)
#    2762         if len(cols) == 1 and isinstance(cols[0], list):
#    2763             cols = cols[0]
# -> 2764         return self._jseq(cols, _to_java_column)
#    2765
#    2766     def _sort_cols(
#
# ...

# %%
# Step 2: Data Cleaning
# Remove duplicates
duplicate_record1 = duplicate_record1.dropDuplicates()
duplicate_record2 = duplicate_record2.dropDuplicates()
# Handle missing values
# Handle missing values and drop rows where age is null or zero
OnlineRetail1 = OnlineRetail1.na.fill({"Quantity": 0, "UnitPrice": 0})
OnlineRetail2 = OnlineRetail2.na.fill({"Quantity": 0, "UnitPrice": 0})
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-15-edd253fb1cad> in <cell line: 3>()
#       1 # Step 2: Data Cleaning
#       2 # Remove duplicates
# ----> 3 duplicate_record1 = duplicate_record1.dropDuplicates()
#       4 duplicate_record2 = duplicate_record2.dropDuplicates()
#       5 # Handle missing values
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py in dropDuplicates(self, subset)
#    4215
#    4216         if subset is None:
# -> 4217             jdf = self._jdf.dropDuplicates()
#    4218         else:
#    4219             jdf = self._jdf.dropDuplicates(self._jseq(subset))
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1319             proto.END_COMMAND_PART
#    1320
# -> 1321         answer = self.gateway_client.send_command(command)
# ...

# %%
# step 3: Data Aggregation : calculate sale = quantiy * UnitPrice
from pyspark.sql.functions import col, sum as _sum

OnlineRetail1 = OnlineRetail1.withColumn("amount", col("Quantity") * col("UnitPrice"))
total_sales_per_StockCode1 = OnlineRetail1.groupBy("StockCode").agg(_sum("amount").alias("total_sales"))

OnlineRetail2 = OnlineRetail2.withColumn("amount", col("Quantity") * col("UnitPrice"))
total_sales_per_StockCode2 = OnlineRetail2.groupBy("StockCode").agg(_sum("amount").alias("total_sales"))
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-15-3ef3c8014d3b> in <cell line: 4>()
#       2 from pyspark.sql.functions import col, sum as _sum
#       3
# ----> 4 OnlineRetail1 = OnlineRetail1.withColumn("amount", col("Quantity") * col("UnitPrice"))
#       5 total_sales_per_StockCode1 = OnlineRetail1.groupBy("StockCode").agg(_sum("amount").alias("total_sales"))
#       6
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/utils.py in wrapped(*args, **kwargs)
#     172             return getattr(functions, f.__name__)(*args, **kwargs)
#     173         else:
# --> 174             return f(*args, **kwargs)
#     175
#     176     return cast(FuncT, wrapped)
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/functions.py in col(col)
#     221     Column<'x'>
#     222     """
# --> 223     return _invoke_function("col", col)
#     224
#     225
#
# ...

# %%
# Step4: Join 2 datasets into 1 unified dataset and loading
unified_data = OnlineRetail1.unionByName(OnlineRetail2)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# <ipython-input-44-81d188c045f6> in <cell line: 2>()
#       1 # Step4: Join 2 datasets into 1 unified dataset and loading
# ----> 2 unified_data = OnlineRetail1.unionByName(OnlineRetail2)
#
# /usr/local/lib/python3.10/dist-packages/pyspark/sql/dataframe.py in unionByName(self, other, allowMissingColumns)
#    4039         +----+----+----+----+----+----+
#    4040         """
# -> 4041         return DataFrame(self._jdf.unionByName(other._jdf, allowMissingColumns), self.sparkSession)
#    4042
#    4043     def intersect(self, other: "DataFrame") -> "DataFrame":
#
# /usr/local/lib/python3.10/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1319             proto.END_COMMAND_PART
#    1320
# -> 1321         answer = self.gateway_client.send_command(command)
#    1322         return_value = get_return_value(
# ...

# %%
# Output unified_data data
unified_data.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-8048d8456cae> in <cell line: 2>()
#       1 # Output unified_data data
# ----> 2 unified_data.show()
#       3
#
# NameError: name 'unified_data' is not defined

# %%
import os

java_home = os.environ.get('JAVA_HOME')
if java_home:
    print("JAVA_HOME is set to:", java_home)
else:
    print("JAVA_HOME is not set.")
# Out:
# JAVA_HOME is not set.

# %%
unified_data.show()

# %%
# Stop Spark session
spark.stop()
